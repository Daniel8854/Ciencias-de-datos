# %%
import pandas as pd
df = pd.read_csv("siniestralidad_2016_2024.csv", sep=";", encoding="latin-1")
#se usa separador ; y codificación latin-1 para leer correctamente el archivo CSV
#esto debido a que el archivo contiene caracteres especiales y el separador de campos es punto y coma
print(f"Cargados {len(df):,} registros")
df.head()
# Out:
# C:\Users\ACER NITRO V16\AppData\Local\Temp\ipykernel_23048\2304123797.py:2: DtypeWarning: Columns (0: Código, 1: Dirección reporte) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("siniestralidad_2016_2024.csv", sep=";", encoding="latin-1")
# Cargados 371,003 registros
#   Código      Fecha Tipo confirmado            Dirección reporte  \
# 0  96159  1/01/2016      Solo daños     Carrera 56 Con Calle 1 A
# 1  96160  1/01/2016        Negativo  Calle 72 O Con Carrera 28 H
# 2  96161  1/01/2016   Con lesionado     Carrera 94 Con Calle 4 C
# 3  96162  1/01/2016   Con lesionado     Carrera 8 A Con Calle 44
# 4  96163  1/01/2016        Negativo  Carrera 28 H Con Calle 72 M
#
#   Tipo clase de accidente Tipo clase de accidente.1 Tipo confirmado.1  \
# 0                       .                         .        Solo Da?os
# 1                       .                         .          Negativo
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 371003 entries, 0 to 371002
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Código                        371002 non-null  object
#  1   Fecha                         371002 non-null  str
#  2   Tipo confirmado               371002 non-null  str
#  3   Dirección reporte             189410 non-null  str
#  4   Tipo clase de accidente       371002 non-null  str
#  5   Tipo clase de accidente.1     371002 non-null  str
#  6   Tipo confirmado.1             371003 non-null  str
#  7   Medio de reporte              371003 non-null  str
#  8   Numero vehículos              371003 non-null  str
#  9   Tipo de vehículos implicados  371003 non-null  str
# dtypes: object(1), str(9)
# memory usage: 48.6+ MB
